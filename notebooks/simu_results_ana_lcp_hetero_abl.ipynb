# %%
import sys
sys.path.append("../mypkg")

# %%
from constants import RES_ROOT, FIG_ROOT, DATA_ROOT, MID_ROOT
from utils.misc import load_pkl, save_pkl, merge_intervals
from utils.colors import qual_cmap
from utils.stats import weighted_quantile

# %%
# %load_ext autoreload
# %autoreload 2
# 0,1, 2, 3, be careful about the space

# %%
import torch
import scipy.stats as ss
import numpy as np
from easydict import EasyDict as edict
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict as ddict
from tqdm import tqdm, trange
import random
from joblib import Parallel, delayed
import pandas as pd
from pprint import pprint
plt.style.use(FIG_ROOT/"base.mplstyle")

# %%
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
from collections import defaultdict as ddict
def fil_name2paras(fil_name):
    """plz be careful about 0.1 and 1
    """
    tmp = fil_name.split("_")
    paras = {}
    for itm in tmp:
        if '--' in itm:
            k, v = itm.split("--")
            v = f"0.{v}"
        elif '-' in itm:
            k, v = itm.split("-")
            # to be compatible with old simu
            if v.startswith("0"):
                v = f"0.{v}"
        else:
            continue
        
        if k.startswith("T"):
            k = "n_T"
        elif k.startswith("decay"):
            k = "weight_decay"
        elif k.startswith("infeat"):
            k = "n_infeat"
        paras[k] = float(v)
    paras["rep"] = int(tmp[1])
    return paras

# %%
setting = "setting4"
d = 10 # vary d 10, 300
cs = [0, 0.02, 0.04, 0.06, 0.08, 0.1, 0.2, 0.4, 0.8, 1.2]
Ks = [10, 20, 40, 80, 160, 320]
# Out:
# [10, 20, 40, 80, 160, 320]

# %%
# get results of DDIM and naive
def _add_res(res, key, dict_res):
    if key not in res.keys():
        key = "L" + key
        if key not in res.keys():
            return None
    dict_res["Len"].append(res[key][-1])
    dict_res["ITE"].append(res[key][0])
    if key.startswith("DDIM"):
        dict_res["method"].append("L"+key)
    else:
        dict_res["method"].append(key)
    for ky, v in cur_paras.items():
        dict_res[ky].append(v)
    dict_res["c"].append(c)
    dict_res["K"].append(K)
        
our_res = ddict(list)
for c in cs:
    for K in Ks:
        res_dir = RES_ROOT/f"simuLCPHETEROK_{setting}_d{d}_n10000_c{c*100:.0f}_K{K}"
        all_fils = list(res_dir.glob("*n_T-*.pkl"));
        for fil in all_fils:
            cur_paras = fil_name2paras(fil.stem);
            res = load_pkl(fil, verbose=False);
            
            for ky in res.keys():
                _add_res(res, key=ky, dict_res=our_res)
        
our_res_df = pd.DataFrame(our_res);

# %%
def _get_dataset(name):
    name = name.split("_ep")[0].split("_val")[0]
    if name.endswith("1"):
        dat_set = "set1"
    elif name.endswith("2"):
        dat_set = "set2"
    elif name.endswith("2c"):
        dat_set = "set2c"
    else:
        dat_set = "all_data"
    return dat_set

def _get_nep(x):
    vs = x.split("_ep")
    if len(vs) == 1:
        return 2000
    elif len(vs) == 2:
        return int(vs[1].split("_")[0])
_raw_method=lambda x: x.split("_")[0].split("1")[0].split("2")[0]
our_res_df["data_set"] = our_res_df["method"].map(_get_dataset);
our_res_df["is_val"] = our_res_df["method"].map(lambda x: x.endswith("val"));
our_res_df["nep"] = our_res_df["method"].map(_get_nep);
our_res_df["method_raw"] = our_res_df["method"].map(_raw_method)

# %% [markdown]
# # Select com for each rep

# %%
# get opt obs based on val set
def _get_opt_obs_given_repix(rep_ix, c, K, 
                             data_set, all_res_df, 
                             method_key="DDPM", cutoff=None):
    cols = ["method_raw", "lr", "n_infeat", "n_T", 
            "weight_decay", "upblk", "downblk", 
            "rep", "c", "nep", "data_set", "K"]
    kpidx = np.bitwise_and(all_res_df["rep"] == rep_ix, all_res_df["is_val"])
    kpidx = np.bitwise_and(kpidx, all_res_df["method_raw"]==method_key)
    kpidx = np.bitwise_and(kpidx, all_res_df["data_set"]==data_set)
    kpidx = np.bitwise_and(kpidx, all_res_df["c"] == c)
    kpidx = np.bitwise_and(kpidx, all_res_df["K"] == K)
    
    
    if cutoff is not None:
        kpidx1 = np.bitwise_and(kpidx, all_res_df["ITE"]>cutoff)
    if kpidx1.sum() > 0:
        kpidx = kpidx1
        best_val = all_res_df[kpidx].sort_values(by="Len").iloc[0]
    else:
        # if no ITE > target, use the one with largest probs
        best_val = all_res_df[kpidx].sort_values(by="ITE").iloc[-1]
        
    mask = np.ones(all_res_df.shape[0], dtype=bool)
    mask = np.bitwise_and(mask, all_res_df["is_val"] == False)
    for col in cols:
        v = best_val[col]
        mask = np.bitwise_and(mask, all_res_df[col] == v)
    return all_res_df[mask]

# %%
data_sets = ["set1"]
best_res = []
cutoff = 0.95
for cur_rep in trange(50):
    for data_set in data_sets:
        for c in cs:
            for K in Ks:
                best_res.append(
                    _get_opt_obs_given_repix(
                        rep_ix = cur_rep, 
                        c=c, 
                        K=K, 
                        data_set=data_set, 
                        all_res_df=our_res_df, 
                        method_key="LDDIM", 
                        cutoff=cutoff
                    )
                )
    
best_res = pd.concat(best_res);
best_res1 = best_res.copy();

# %%
# put the results together
save_pkl(MID_ROOT/f"tmpdf_{setting}_d{d}_abl.pkl", best_res1);
# Out:
# Save to /data/rajlab1/user_data/jin/MyResearch/DG-CITE_paper/notebooks/../mypkg/../mid_results/tmpdf_setting5_d300_abl.pkl

# %% [markdown]
# # Plot

# %%
d = 10
# Out:
# 10

# %%
best_res = load_pkl(MID_ROOT/f"tmpdf_{setting}_d{d}_abl.pkl");
best_res1 = best_res.copy();
# Out:
# Load file /data/rajlab1/user_data/jin/MyResearch/DG-CITE_paper/notebooks/../mypkg/../mid_results/tmpdf_setting5_d10_abl.pkl

# %%
kp_cols = ["Len", "ITE", "method_raw", "rep", "data_set", "c1", "K"]
# put the results together

best_res["c1"] = best_res1["c"].map(lambda x: x if x > 0 else np.inf)
best_res = best_res[kp_cols];

# %%
data_set = "set1"
ITEmats = best_res.groupby(["data_set", "c1", "K"])["ITE"].mean().unstack()
Lenmats = best_res.groupby(["data_set", "c1", "K"])["Len"].mean().unstack();
sel_idx = [ix for ix in Lenmats.index[:] if ix[0].startswith(data_set)]

ITEmat = ITEmats.loc[sel_idx]
ITEmat.index = [ix[-1] for ix in ITEmat.index ]
Lenmat = Lenmats.loc[sel_idx]
Lenmat.index = [ix[-1] for ix in Lenmat.index ];

# %%
plt.figure(figsize=[10, 5])
sns.heatmap(Lenmat, annot=Lenmat, fmt=".2f", cmap="Oranges")
plt.ylabel("Bandwidth factor (c)")
plt.savefig(FIG_ROOT/f"abl_{setting}_d{d}_{data_set}_Len.jpg")

plt.figure(figsize=[10, 5])
sns.heatmap(ITEmat, annot=True, fmt=".3f", cmap="RdBu_r", center=0.95)
plt.ylabel("Bandwidth factor (c)")
plt.savefig(FIG_ROOT/f"abl_{setting}_d{d}_{data_set}_prob.jpg")
